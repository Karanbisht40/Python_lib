# %% [markdown]
# Pivot Tables

# %%
import numpy as np
import pandas as pd

# %%
data = {
    'Date': pd.date_range('2023-01-01', periods=20),
    'Product': ['A', 'B', 'C', 'D'] * 5,
    'Region': ['East', 'West', 'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West',
               'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West', 'North', 'South'],
    'Sales': np.random.randint(100, 1000, 20),
    'Units': np.random.randint(10, 100, 20),
    'Rep': ['John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary',
            'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice']
}

df = pd.DataFrame(data)
df['Month'] = df['Date'].dt.month_name()
df['Quarter'] = 'Q' + df['Date'].dt.quarter.astype(str)
df
# Out:
#          Date Product Region  Sales  Units    Rep    Month Quarter
# 0  2023-01-01       A   East    341     62   John  January      Q1
# 1  2023-01-02       B   West    600     91   Mary  January      Q1
# 2  2023-01-03       C  North    981     36    Bob  January      Q1
# 3  2023-01-04       D  South    741     33  Alice  January      Q1
# 4  2023-01-05       A   East    399     42   John  January      Q1
# 5  2023-01-06       B   West    792     45   Mary  January      Q1
# 6  2023-01-07       C  North    866     13    Bob  January      Q1
# 7  2023-01-08       D  South    231     12  Alice  January      Q1
# 8  2023-01-09       A   East    670     94   John  January      Q1
# 9  2023-01-10       B   West    357     62   Mary  January      Q1
# 10 2023-01-11       C  North    434     59    Bob  January      Q1
# 11 2023-01-12       D  South    348     29  Alice  January      Q1
# 12 2023-01-13       A   East    938     18   John  January      Q1
# 13 2023-01-14       B   West    269     15   Mary  January      Q1
# 14 2023-01-15       C  North    365     39    Bob  January      Q1
# 15 2023-01-16       D  South    638     53  Alice  January      Q1
# 16 2023-01-17       A   East    339     66   John  January      Q1
# 17 2023-01-18       B   West    551     62   Mary  January      Q1
# 18 2023-01-19       C  North    521     19    Bob  January      Q1
# 19 2023-01-20       D  South    609     23  Alice  January      Q1

# %%
pd.pivot_table(
    df,
    values="Sales",
    index="Region",
    columns="Product",
    aggfunc="median"
)
# Out:
# Product      A      B      C      D
# Region
# East     399.0    NaN    NaN    NaN
# North      NaN    NaN  521.0    NaN
# South      NaN    NaN    NaN  609.0
# West       NaN  551.0    NaN    NaN

# %%
pivot2 = pd.pivot_table(
    df,
    values=['Sales','Units'],
    index="Region",
    columns="Product",
    aggfunc="median"
)
pivot2
# Out:
#          Sales                      Units
# Product      A      B      C      D     A     B     C     D
# Region
# East     399.0    NaN    NaN    NaN  62.0   NaN   NaN   NaN
# North      NaN    NaN  521.0    NaN   NaN   NaN  36.0   NaN
# South      NaN    NaN    NaN  609.0   NaN   NaN   NaN  29.0
# West       NaN  551.0    NaN    NaN   NaN  62.0   NaN   NaN

# %% [markdown]
# cross tabs

# %%
pd.crosstab(
    df['Region'],
    df['Product']
)
# Out:
# Product  A  B  C  D
# Region
# East     5  0  0  0
# North    0  0  5  0
# South    0  0  0  5
# West     0  5  0  0

# %%
pd.crosstab(
    df['Product'],
    df['Region'],
    normalize=True
)
# Out:
# Region   East  North  South  West
# Product
# A        0.25   0.00   0.00  0.00
# B        0.00   0.00   0.00  0.25
# C        0.00   0.25   0.00  0.00
# D        0.00   0.00   0.25  0.00

# %%
pd.crosstab(
    df['Product'],
    df['Region'],
    margins=True
)
# Out:
# Region   East  North  South  West  All
# Product
# A           5      0      0     0    5
# B           0      0      0     5    5
# C           0      5      0     0    5
# D           0      0      5     0    5
# All         5      5      5     5   20
