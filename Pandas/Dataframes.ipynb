# %% [markdown]
# Data frames - creating

# %%
import numpy as np
import pandas as pd

# %%
data = {
    'Name': ['John', 'Anna', 'Peter', 'Linda'],
    'Age': [28, 34, 29, 42],
    'City': ['New York', 'Paris', 'Berlin', 'London'],
    'Salary': [65000, 70000, 62000, 85000]
}

df = pd.DataFrame(data)
df
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
#using list
data_list = [
    ['John', 28, 'New York', 65000],
    ['Anna', 34, 'Paris', 70000],
    ['Peter', 29, 'Berlin', 62000],
    ['Linda', 42, 'London', 85000]
]
df2 = pd.DataFrame(data_list)
columns =["name","age", "city","salary"]
df2 = pd.DataFrame(data_list, columns=columns)
df2
# Out:
#     name  age      city  salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
#Create a DataFrame from a List of Dictionaries
import pandas as pd

data = [
    {"Name": "Alice", "Age": 20},
    {"Name": "Bob", "Age": 22},
    {"Name": "Charlie", "Age": 21}
]

df = pd.DataFrame(data)

print(df)
# Out:
#       Name  Age
# 0    Alice   20
# 1      Bob   22
# 2  Charlie   21

# %%
#selection and indxing of column
df2
# Out:
#     name  age      city  salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df2["name"]  #single column access
# Out:
# 0     John
# 1     Anna
# 2    Peter
# 3    Linda
# Name: name, dtype: object

# %%
df2[["name", "city"]]    #multi column access
# Out:
#     name      city
# 0   John  New York
# 1   Anna     Paris
# 2  Peter    Berlin
# 3  Linda    London

# %%
#new column
df2["Designation"]= ["doctor","eng","doc","eng"]

# %%
df2
# Out:
#     name  age      city  salary Designation
# 0   John   28  New York   65000      doctor
# 1   Anna   34     Paris   70000         eng
# 2  Peter   29    Berlin   62000         doc
# 3  Linda   42    London   85000         eng

# %%
#remove columns temporary
df2.drop("Designation",axis=1)
# Out:
#     name  age      city  salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df2
# Out:
#     name  age
# 0   John   28
# 1   Anna   34
# 2  Peter   29
# 3  Linda   42

# %%
#remove column permanent
df2.drop("Designation",axis=1, inplace=True)

# %%
df2
# Out:
#     name  age      city  salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
#remove multiple columns
df2.drop(["city","salary"],axis=1)
# Out:
#     name  age
# 0   John   28
# 1   Anna   34
# 2  Peter   29
# 3  Linda   42

# %%
df2
# Out:
#     name  age      city  salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
#remove row
df2.drop(0,axis=0)
# Out:
#     name  age    city  salary
# 1   Anna   34   Paris   70000
# 2  Peter   29  Berlin   62000
# 3  Linda   42  London   85000

# %% [markdown]
# selecting rows

# %%
df2.loc[1]
# Out:
# name       Anna
# age          34
# city      Paris
# salary    70000
# Name: 1, dtype: object

# %%
df2.loc[[1,2]]
# Out:
#     name  age    city  salary
# 1   Anna   34   Paris   70000
# 2  Peter   29  Berlin   62000

# %%
df2.iloc[3]
# Out:
# name       Linda
# age           42
# city      London
# salary     85000
# Name: 3, dtype: object

# %% [markdown]
# Selecting subsets of rows and columns

# %%
df2
# Out:
#     name  age      city  salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df2.loc[[0,1]][["city","salary"]]
# Out:
#        city  salary
# 0  New York   65000
# 1     Paris   70000

# %%
df2.loc[[2,3]][["name","age"]]
# Out:
#     name  age
# 2  Peter   29
# 3  Linda   42

# %% [markdown]
# Conditional selection

# %%
df2
# Out:
#     name  age      city  salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
#i want people whose age is above the 30
df2[df2["age"]>30]
# Out:
#     name  age    city  salary
# 1   Anna   34   Paris   70000
# 3  Linda   42  London   85000

# %%
#i want people whose age is above 30 and live in paris
df2[(df2["age"]>30) & (df2["city"] == 'Paris')]
# Out:
#    name  age   city  salary
# 1  Anna   34  Paris   70000

# %%
df2[(df2["age"]>30) | (df2["salary"]>60000)]  #or
# Out:
#     name  age      city  salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df2[~(df2["age"]>30)]   #not
# Out:
#     name  age      city  salary
# 0   John   28  New York   65000
# 2  Peter   29    Berlin   62000
