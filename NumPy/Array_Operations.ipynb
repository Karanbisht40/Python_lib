# %%
import numpy as np

# %%
a1= np.array([1,2,3,4,5])
a2= np.array([6,6,7,8,9])

# %%
a1+ a2
# Out:
# array([ 7,  8, 10, 12, 14])

# %%
a1-a2
# Out:
# array([-5, -4, -4, -4, -4])

# %%
a1* a2
# Out:
# array([ 6, 12, 21, 32, 45])

# %%
a1 /a2
# Out:
# array([0.16666667, 0.33333333, 0.42857143, 0.5       , 0.55555556])

# %%
a1 //a2
# Out:
# array([0, 0, 0, 0, 0])

# %%
a1 ** a2
# Out:
# array([      1,      64,    2187,   65536, 1953125])

# %%
a1 % a2
# Out:
# array([1, 2, 3, 4, 5])

# %% [markdown]
# Broadcasting

# %%
arr = np.array([10,20,30,40,50])

# %%
print(arr +5)
# Out:
# [15 25 35 45 55]

# %%
arr= np.array([[10,20,30,40],[12,13,14,15]])

# %%
print(arr +5)
# Out:
# [[15 25 35 45]
#  [17 18 19 20]]

# %%
A = np.array([
    [1,2],
    [3,4]
])

print(A * 2)
# Out:
# [[2 4]
#  [6 8]]

# %%
import numpy as np

a = np.array([2, 4, 6])
b = np.array([[1, 3, 5], [7, 9, 11]])
res = a + b
print(res)
# Out:
# [[ 3  7 11]
#  [ 9 13 17]]

# %% [markdown]
# Deep and Shallow copy
