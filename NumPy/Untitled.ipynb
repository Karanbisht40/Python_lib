# %%
import numpy as np

marks = np.array([
    [88,92,85,78],
    [76,85,90,89],
    [92,88,95,94],
    [65,70,72,68],
    [90,95,91,99]
])

# %%
#total & avg marks per student
tot= np.sum(marks, axis=1)
avg= np.mean(marks,axis=1)
print(tot)
print(avg)
# Out:
# [343 340 369 275 375]
# [85.75 85.   92.25 68.75 93.75]
